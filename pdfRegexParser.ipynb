# %% [markdown]
# # MNBlackNewspaperIndex Regex Parse

# %%
import re #regex
import PyPDF2 #read in pdf
import shutil # copy working file
import pandas as pd

# %%
# import the acrobat ocr'd pdf file,
# keeps the newline formatting of the original, easier to parse than the .txt
with open('MNBlackNewspaperIndex.pdf', 'rb') as file:
    reader = PyPDF2.PdfReader(file)
    # extract the text
    ocr_text = []
    for page in reader.pages:
        text = page.extract_text()
        ocr_text.append(text)

# %%
# check that length of list matches number of pages, should be 129
len(ocr_text)
# Out:
# 129

# %%
# write out the ocr_text as a text file with the line ending as the break
with open('MNBlackNewspaperIndexRaw.txt', 'w') as outfile:
    outfile.write("\n".join(ocr_text))

# %%
# # write out a copy of the text file to edit and work on
# # Do this once and comment it out to prevent overwrite

# source_file = 'MNBlackNewspaperIndexRaw.txt'  # Path to the source file
# destination_file = 'MNBlackNewspaperIndexWorking.txt'  # Path to the destination file (renamed copy)

# # Make a copy of the file with the new name
# shutil.copyfile(source_file, destination_file)
# Out:
# 'MNBlackNewspaperIndexWorking.txt'

# %%
# read in the working file 
with open('MNBlackNewspaperIndexWorking.txt', 'r') as file:
    lines = file.readlines()
    dict = {}
    for i, line in enumerate(lines):
        dict[i] = line.strip()

# %%
# Convert the dictionary to a DataFrame
df = pd.DataFrame.from_dict(dict, orient='index', columns=['blob'])

# %%
df
# Out:
#                                                    blob
# 0     Advertisement Rural real estate offered for sa...
# 1     Albright, Joseph Duluthian gets WPA post TCH 1...
# 2     Albright, Joseph Open letter calls for statewi...
# 3     Albright, Joseph Part of Black democrats worki...
# 4     Albright, Joseph Addresses FL convention in Du...
# ...                                                 ...
# 5853  YMCA/YWCA Report on bias at U of M NWM 6-10-19...
# 5854  Young, Jeremiah U of M professor refuses seat ...
# 5855  Young, Jeremiah Prof apparently reprimanded fo...
# 5856  Young, Joe Former TC real estate agent kills h...
# 5857  Zamora, P. M. "Mexican" talks before St. Paul ...
#
# [5858 rows x 1 columns]

# %%
# Create new columns for the regex groups, run the string extract on the clumn of the DF with the text,
# 
df[['blob1', 'publication', 'month', 'day', 'year', 'page', 'column']] = df['blob'].str.extract('^(?P<blob1>.+) (?P<publication>[A-Z]{2,}) (?P<month>\d+)-(?P<day>\d+)-(?P<year>\d{4}) p\s?(?P<page>\w) c\s?(?P<column>\w)')

# %%
df.head(10)
# Out:
#                                                 blob
# 0  Advertisement Rural real estate offered for sa...  \
# 1  Albright, Joseph Duluthian gets WPA post TCH 1...
# 2  Albright, Joseph Open letter calls for statewi...
# 3  Albright, Joseph Part of Black democrats worki...
# 4  Albright, Joseph Addresses FL convention in Du...
# 5  Albright, Joseph Loses his state accounting jo...
# 6  Albright, Joseph Involved in messy divorce fro...
# 7  Albright, Joseph Gets local job with food stam...
# 8  Albright, Joseph Gives strong address at Eucha...
# 9  Albright, Joseph Update on his California mili...
#
#                                                blob1 publication month  day
# 0   Advertisement Rural real estate offered for sale          AP    11   27  \
# 1           Albright, Joseph Duluthian gets WPA post         TCH    12   21
# 2  Albright, Joseph Open letter calls for statewi...         MSP     5    1
# 3  Albright, Joseph Part of Black democrats worki...         MSP     9    4
# 4  Albright, Joseph Addresses FL convention in Du...         MSP     4    1
# 5  Albright, Joseph Loses his state accounting jo...         MSP     8    4
# 6  Albright, Joseph Involved in messy divorce fro...         MSP    10   10
# 7  Albright, Joseph Gets local job with food stam...         MSP    12    1
# 8                                                NaN         NaN   NaN  NaN
# 9  Albright, Joseph Update on his California mili...         MSP     2   19
#
#    year page column
# 0  1915    4      2
# 1  1935    1      2
# 2  1936    1      6
# 3  1936    1      6
# 4  1938    1      4
# 5  1939    1      5
# 6  1939    1      4
# 7  1939    1      6
# 8   NaN  NaN    NaN
# 9  1943    3      4

# %%
# Grab the rows where the regex had problems to find errors/ manually clean and correct

df[df['blob1'].isna()]
# Out:
#                                                    blob blob1 publication
# 8     Albright, Joseph Gives strong address at Eucha...   NaN         NaN  \
# 14     Baseball Douglass Base Ball Club AP 6-12-1897 p3   NaN         NaN
# 190   Real estate Big real estate ad luring Blacks t...   NaN         NaN
# 223   Withers, Rev. M. W. Photo of Fergus Falls Bapt...   NaN         NaN
# 259   Adams, J. Q. 25th anniversary of Appeal souven...   NaN         NaN
# ...                                                 ...   ...         ...
# 5793  Wilson, Charles Photographic assistant to Harr...   NaN         NaN
# 5803  Wilson, Woodrow William Trotter speaks against...   NaN         NaN
# 5806  Winston, Eliza Obit for white man who played r...   NaN         NaN
# 5825                  World War I (see also Home Guard)   NaN         NaN
# 5853  YMCA/YWCA Report on bias at U of M NWM 6-10-19...   NaN         NaN
#
#      month  day year page column
# 8      NaN  NaN  NaN  NaN    NaN
# 14     NaN  NaN  NaN  NaN    NaN
# 190    NaN  NaN  NaN  NaN    NaN
# 223    NaN  NaN  NaN  NaN    NaN
# 259    NaN  NaN  NaN  NaN    NaN
# ...    ...  ...  ...  ...    ...
# 5793   NaN  NaN  NaN  NaN    NaN
# 5803   NaN  NaN  NaN  NaN    NaN
# 5806   NaN  NaN  NaN  NaN    NaN
# 5825   NaN  NaN  NaN  NaN    NaN
# 5853   NaN  NaN  NaN  NaN    NaN
#
# [183 rows x 8 columns]

# %%
df.iloc[9]
# Out:
# blob           Albright, Joseph Update on his California mili...
# blob1          Albright, Joseph Update on his California mili...
# publication                                                  MSP
# month                                                          2
# day                                                           19
# year                                                        1943
# page                                                           3
# Name: 9, dtype: object

# %% [markdown]
# ## Desired Output
# - spreadsheet
#     - columns
#         - subj_name
#         - description
#         - newspaper
#         - year
#         - date
#         - page
#
# ## Notes on text
# - first few lines are key to newspaper
#     - remove
# - if name
#     - Last, First
# - if subject
#     - SubjectA SubjectB
#         - how to handle this? Only capture first word? exceptions? if else?
#
# ## Approach
#
# - newspaper
#     - do a find and replace to get full titles based on key
